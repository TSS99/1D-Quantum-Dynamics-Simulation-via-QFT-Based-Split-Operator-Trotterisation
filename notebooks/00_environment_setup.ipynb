# %% [markdown]
# # 00. Environment Setup
#
# This notebook verifies the local environment, the shared methods notebook, and the output folders used by the publication workflow.

# %%
from pathlib import Path
import importlib.metadata as ilmd
import platform
import sys

import pandas as pd
from IPython.display import Markdown, display

EXPECTED_ROOT = Path(r"D:\CDAC Projects\Simulating_1D_Sytems_Trotterization\EPJ Plus paper\Codex").resolve()
PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "notebooks").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent.resolve()
if PROJECT_ROOT != EXPECTED_ROOT:
    raise RuntimeError(f"Project root mismatch. Expected {EXPECTED_ROOT}, found {PROJECT_ROOT}.")

FIGURES_DIR = PROJECT_ROOT / "figures"
TABLES_DIR = PROJECT_ROOT / "tables"
COMMON_NOTEBOOK = PROJECT_ROOT / "notebooks" / "00_common_qft_split_functions.ipynb"
for directory in (FIGURES_DIR, TABLES_DIR):
    directory.mkdir(parents=True, exist_ok=True)
if not COMMON_NOTEBOOK.exists():
    raise FileNotFoundError(f"Missing common methods notebook: {COMMON_NOTEBOOK}")

packages = ["qiskit", "numpy", "scipy", "matplotlib", "pandas", "jupyter", "ipykernel", "pylatexenc"]
version_df = pd.DataFrame([{"package": package, "version": ilmd.version(package)} for package in packages])
summary_df = pd.DataFrame(
    [
        {
            "python_executable": sys.executable,
            "python_version": sys.version.split()[0],
            "platform": platform.platform(),
            "project_root": str(PROJECT_ROOT),
            "common_methods_notebook": str(COMMON_NOTEBOOK),
            "figures_dir": str(FIGURES_DIR),
            "tables_dir": str(TABLES_DIR),
        }
    ]
)

display(Markdown("## Environment Summary"))
display(summary_df)
display(Markdown("## Package Versions"))
display(version_df)
print("Environment setup check completed successfully.")
# Out:
# ## Environment Summary
#                                    python_executable python_version  \
# 0  D:\CDAC Projects\Simulating_1D_Sytems_Trotteri...         3.11.6
#
#                     platform  \
# 0  Windows-10-10.0.26200-SP0
#
#                                         project_root  \
# 0  D:\CDAC Projects\Simulating_1D_Sytems_Trotteri...
#
#                              common_methods_notebook  \
# 0  D:\CDAC Projects\Simulating_1D_Sytems_Trotteri...
#
#                                          figures_dir  \
# 0  D:\CDAC Projects\Simulating_1D_Sytems_Trotteri...
#
#                                           tables_dir
# 0  D:\CDAC Projects\Simulating_1D_Sytems_Trotteri...
# ## Package Versions
#       package version
# 0      qiskit   2.4.0
# 1       numpy   2.4.4
# 2       scipy  1.17.1
# 3  matplotlib  3.10.8
# 4      pandas   3.0.2
# 5     jupyter   1.1.1
# 6   ipykernel   7.2.0
# 7  pylatexenc    2.10
# Environment setup check completed successfully.

# %% [markdown]
# The remaining notebooks load shared methods from `00_common_qft_split_functions.ipynb`. Generated figures are written to `figures/`, and generated tables are written to `tables/`.
